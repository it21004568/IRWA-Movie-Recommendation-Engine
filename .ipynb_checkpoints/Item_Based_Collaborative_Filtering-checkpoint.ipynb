# %% [markdown]
# # Item-Based Collaborating

# %% [markdown]
# ## Step 1: Import Relevant Libraries

# %%
# import relevant libraries for data preprocessingData processing
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Step 2: Importing datastets

# %%
#import the ratings dataset
ratings_df=pd.read_csv('ratings_small.csv')
ratings_df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
#view the ratings meta data
ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100004 entries, 0 to 100003
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100004 non-null  int64
#  1   movieId    100004 non-null  int64
#  2   rating     100004 non-null  float64
#  3   timestamp  100004 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
#load the movies dataset
movies_df = pd.read_csv('movie.csv')
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# ## Step 3: Merging datasets on moviedID column

# %%
# Merge movies and ratings based on common movieID 
df = pd.merge(ratings_df, movies_df, on='movieId', how='inner')
df
# Out:
#        userId  movieId  rating   timestamp  \
# 0           1       31     2.5  1260759144
# 1           7       31     3.0   851868750
# 2          31       31     4.0  1273541953
# 3          32       31     4.0   834828440
# 4          36       31     3.0   847057202
# ...       ...      ...     ...         ...
# 99338     664    64997     2.5  1343761859
# 99339     664    72380     3.5  1344435977
# 99340     665      129     3.0   995232528
# 99341     665     4736     1.0  1010197684
# 99342     668     6425     1.0   993613478
#
#                                       title  \
# 0                    Dangerous Minds (1995)
# 1                    Dangerous Minds (1995)
# 2                    Dangerous Minds (1995)
# 3                    Dangerous Minds (1995)
# 4                    Dangerous Minds (1995)
# ...                                     ...
# 99338              War of the Worlds (2005)
# 99339                       Box, The (2009)
# ...

# %% [markdown]
# ## Step 4: Exploratory Data Analysis (EDA)

# %%
## Aggregate by movie
aggregate_ratings = df.groupby('title').agg(mean_rating=('rating', 'mean'),
                                            number_of_ratings=('rating', 'count'),
                                            genres=('genres', '|'.join)).reset_index()
# Keep the movies with over 100 ratings
agg_ratings_MT100 = aggregate_ratings[aggregate_ratings['number_of_ratings']>100]

agg_ratings_MT100.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149 entries, 58 to 8694
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              149 non-null    object
#  1   mean_rating        149 non-null    float64
#  2   number_of_ratings  149 non-null    int64
#  3   genres             149 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 5.8+ KB

# %%
# Check popular movies
agg_ratings_MT100.sort_values(by='number_of_ratings', ascending=False)
# Out:
#                                           title  mean_rating  \
# 2874                        Forrest Gump (1994)     4.054252
# 6262                        Pulp Fiction (1994)     4.256173
# 6941           Shawshank Redemption, The (1994)     4.487138
# 7020           Silence of the Lambs, The (1991)     4.138158
# 7336  Star Wars: Episode IV - A New Hope (1977)     4.221649
# ...                                         ...          ...
# 4298                   Kill Bill: Vol. 2 (2004)     3.665049
# 5489                            Net, The (1995)     3.102941
# 4514                   Leaving Las Vegas (1995)     3.742574
# 6964                        Shining, The (1980)     4.029703
# 8497             While You Were Sleeping (1995)     3.440594
#
#       number_of_ratings                                             genres
# 2874                341  Comedy|Drama|Romance|War|Comedy|Drama|Romance|...
# 6262                324  Comedy|Crime|Drama|Thriller|Comedy|Crime|Drama...
# ...

# %%
# Visulization to check the correlation between the average rating and the number of ratings
sns.jointplot(x='mean_rating', y='number_of_ratings', data=agg_ratings_MT100)

# %%
# Merge data
df_MT100 = pd.merge(df, agg_ratings_MT100[['title']], on='title', how='inner')
df_MT100.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22463 entries, 0 to 22462
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userId     22463 non-null  int64
#  1   movieId    22463 non-null  int64
#  2   rating     22463 non-null  float64
#  3   timestamp  22463 non-null  int64
#  4   title      22463 non-null  object
#  5   genres     22463 non-null  object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 1.2+ MB

# %%
print(df_MT100)
# Out:
#        userId  movieId  rating   timestamp                    title  \
# 0           2       10     4.0   835355493         GoldenEye (1995)
# 1           4       10     4.0   949810645         GoldenEye (1995)
# 2           7       10     3.0   851869035         GoldenEye (1995)
# 3          15       10     3.0  1093028290         GoldenEye (1995)
# 4          19       10     3.0   855192496         GoldenEye (1995)
# ...       ...      ...     ...         ...                      ...
# 22458     648     8961     4.0  1148160678  Incredibles, The (2004)
# 22459     654     8961     5.0  1145390234  Incredibles, The (2004)
# 22460     660     8961     4.0  1436683470  Incredibles, The (2004)
# 22461     661     8961     4.0  1190266732  Incredibles, The (2004)
# 22462     664     8961     4.0  1441100684  Incredibles, The (2004)
#
#                                            genres
# 0                       Action|Adventure|Thriller
# ...

# %% [markdown]
# ## Step 5: Create Matrix of Movie-User and the values will be the ratings if not watched NAN

# %%
# Create movie-user matrix The rows of the matrix are movies, and the columns of the matrix are users. The value of the matrix is the user rating of the movie if there is a rating. Otherwise, it shows 'NaN'.
matrix_movie_user = df_MT100.pivot_table(index='title', columns='userId', values='rating')
matrix_movie_user.head()
# Out:
# userId                             2    3    4    5    6    7    8    9    \
# title
# 2001: A Space Odyssey (1968)       NaN  NaN  NaN  NaN  NaN  4.0  NaN  NaN
# Ace Ventura: Pet Detective (1994)  NaN  NaN  NaN  3.5  NaN  NaN  NaN  NaN
# Airplane! (1980)                   NaN  NaN  5.0  NaN  NaN  NaN  4.5  NaN
# Aladdin (1992)                     3.0  3.0  5.0  3.5  NaN  4.0  NaN  NaN
# Alien (1979)                       NaN  NaN  5.0  NaN  NaN  NaN  NaN  NaN
#
# userId                             10   11   ...  662  663  664  665  666  \
# title                                        ...
# 2001: A Space Odyssey (1968)       NaN  NaN  ...  NaN  NaN  4.0  NaN  NaN
# Ace Ventura: Pet Detective (1994)  3.0  NaN  ...  2.0  NaN  NaN  3.0  4.0
# Airplane! (1980)                   NaN  NaN  ...  NaN  NaN  NaN  4.0  NaN
# Aladdin (1992)                     NaN  NaN  ...  4.0  NaN  NaN  4.0  3.0
# Alien (1979)                       NaN  NaN  ...  NaN  NaN  3.5  NaN  NaN
#
# ...

# %%
# Normalize user-item matrix
matrix_genre = df_MT100.pivot_table(index='title', columns='userId', values='genres', aggfunc='first')
matrix_genre.head()
# Out:
# userId                                                                     2    \
# title
# 2001: A Space Odyssey (1968)                                               NaN
# Ace Ventura: Pet Detective (1994)                                          NaN
# Airplane! (1980)                                                           NaN
# Aladdin (1992)                     Adventure|Animation|Children|Comedy|Musical
# Alien (1979)                                                               NaN
#
# userId                                                                     3    \
# title
# 2001: A Space Odyssey (1968)                                               NaN
# Ace Ventura: Pet Detective (1994)                                          NaN
# Airplane! (1980)                                                           NaN
# Aladdin (1992)                     Adventure|Animation|Children|Comedy|Musical
# Alien (1979)                                                               NaN
#
# ...

# %% [markdown]
# ## Step 6: Data Normalization

# %%
# Normalize movie-user matrix
matrix_norm = matrix_movie_user.subtract(matrix_movie_user.mean(axis=1), axis = 0)
matrix_norm.head()
# Out:
# userId                                  2         3         4         5    \
# title
# 2001: A Space Odyssey (1968)            NaN       NaN       NaN       NaN
# Ace Ventura: Pet Detective (1994)       NaN       NaN       NaN  0.628571
# Airplane! (1980)                        NaN       NaN  1.179245       NaN
# Aladdin (1992)                    -0.674419 -0.674419  1.325581 -0.174419
# Alien (1979)                            NaN       NaN  1.011811       NaN
#
# userId                             6         7         8    9         10   \
# title
# 2001: A Space Odyssey (1968)       NaN  0.113821       NaN  NaN       NaN
# Ace Ventura: Pet Detective (1994)  NaN       NaN       NaN  NaN  0.128571
# Airplane! (1980)                   NaN       NaN  0.679245  NaN       NaN
# Aladdin (1992)                     NaN  0.325581       NaN  NaN       NaN
# Alien (1979)                       NaN       NaN       NaN  NaN       NaN
#
# ...

# %% [markdown]
# ## Step 7: Calculate Similarity Score

# %%
# Matrix using Pearson correlation
similarity_score= matrix_norm.T.corr()
similarity_score.head()
# Out:
# title                              2001: A Space Odyssey (1968)  \
# title
# 2001: A Space Odyssey (1968)                           1.000000
# Ace Ventura: Pet Detective (1994)                     -0.232466
# Airplane! (1980)                                       0.117408
# Aladdin (1992)                                        -0.210284
# Alien (1979)                                           0.132329
#
# title                              Ace Ventura: Pet Detective (1994)  \
# title
# 2001: A Space Odyssey (1968)                               -0.232466
# Ace Ventura: Pet Detective (1994)                           1.000000
# Airplane! (1980)                                            0.207735
# Aladdin (1992)                                              0.300537
# Alien (1979)                                                0.151234
#
# title                              Airplane! (1980)  Aladdin (1992)  \
# title
# 2001: A Space Odyssey (1968)               0.117408       -0.210284
# ...

# %%
# matrix using cosine similarity
cosine_score = cosine_similarity(matrix_norm.fillna(0))
cosine_score
# Out:
# array([[ 1.        , -0.05433369,  0.03782509, ...,  0.03868648,
#          0.07094169,  0.08399209],
#        [-0.05433369,  1.        ,  0.07836162, ...,  0.07872482,
#          0.04449783,  0.09269084],
#        [ 0.03782509,  0.07836162,  1.        , ...,  0.12787948,
#          0.15264346, -0.00955622],
#        ...,
#        [ 0.03868648,  0.07872482,  0.12787948, ...,  1.        ,
#          0.22654712,  0.03548643],
#        [ 0.07094169,  0.04449783,  0.15264346, ...,  0.22654712,
#          1.        ,  0.06808603],
#        [ 0.08399209,  0.09269084, -0.00955622, ...,  0.03548643,
#          0.06808603,  1.        ]])

# %% [markdown]
# ## Step 8: Predict User's Rating For One Movie

# %%
# Pick a user ID
picked_userid = 3

# Pick a movie
picked_movie = 'Batman (1989)'

# Movies that the target user has watched
picked_userid_watched = pd.DataFrame(matrix_norm[picked_userid].dropna(axis=0, how='all')\
                          .sort_values(ascending=False))\
                          .reset_index()\
                          .rename(columns={picked_userid:'rating'})

picked_userid_watched.head(10)
# Out:
#                               title    rating
# 0                    Titanic (1997)  1.167683
# 1               Forrest Gump (1994)  0.945748
# 2                 Fight Club (1999)  0.821782
# 3        Princess Bride, The (1987)  0.791411
# 4  Shawshank Redemption, The (1994)  0.512862
# 5                    Twister (1996)  0.250000
# 6               Pulp Fiction (1994)  0.243827
# 7        Saving Private Ryan (1998)  0.054974
# 8                 Braveheart (1995)  0.054825
# 9              Trainspotting (1996) -0.141129

# %%
# Similarity score of the movie Batman with all the other movies
picked_movie_similarity_score = similarity_score[[picked_movie]].reset_index().rename(columns={picked_movie:'similarity_score'})

# Rank the similarities between the movies user rated and Batman.
n = 5
picked_userid_watched_similarity = pd.merge(left=picked_userid_watched,
                                            right=picked_movie_similarity_score,
                                            on='title',
                                            how='inner')\
                                     .sort_values('similarity_score', ascending=False)[:5]

# Take a look at the User watched movies with highest similarity
picked_userid_watched_similarity
# Out:
#                                                 title    rating  \
# 12                                      Batman (1989) -0.397959
# 22                            Dark Knight, The (2008) -1.235537
# 14                                  Spider-Man (2002) -0.522388
# 10                   Men in Black (a.k.a. MIB) (1997) -0.163158
# 18  Star Wars: Episode VI - Return of the Jedi (1983) -1.059908
#
#     similarity_score
# 12          1.000000
# 22          0.540793
# 14          0.485885
# 10          0.460651
# 18          0.330281

# %%
# Calculate the predicted rating using weighted average of similarity scores and the ratings from user 1
predicted_rating = round(np.average(picked_userid_watched_similarity['rating'],
                                    weights=picked_userid_watched_similarity['similarity_score']), 6)

print(f'The predicted rating for {picked_movie} by user {picked_userid} is {predicted_rating}' )
# Out:
# The predicted rating for Batman (1989) by user 3 is -0.619382

# %% [markdown]
# ## Step 9: Movie Recommendation

# %%
#Recommendation function considering genre preferences and user ID
def rec_func(picked_user_id, number_of_similar_items, number_of_recommendations):
    # Get unwatched movies for the user
    picked_userid_unwatched = pd.DataFrame(matrix_norm[picked_user_id].isna()).reset_index()
    picked_userid_unwatched = picked_userid_unwatched[picked_userid_unwatched[picked_user_id] == True]['title'].values.tolist()
    picked_userid_watched = pd.DataFrame(matrix_norm[picked_user_id].dropna(axis=0, how='all') \
                                        .sort_values(ascending=False)).reset_index() \
                                        .rename(columns={picked_user_id: 'rating'})

    rating_prediction = {}

    for picked_movie in picked_userid_unwatched:
        # Extract genre information for the picked movie
        picked_movie_genre = movies_df[movies_df['title'] == picked_movie]['genres'].values[0]

        # Filter movies in the same genre as the picked movie
        same_genre_movies = movies_df[movies_df['genres'].str.contains(picked_movie_genre)]

        # Ensure the titles in the user's watched movies match the titles in the similarity_score matrix
        user_watched_same_genre = picked_userid_watched[picked_userid_watched['title'].isin(same_genre_movies['title'])]

        # Calculate the predicted rating for the picked movie in the same genre
        if not user_watched_same_genre.empty:
            weighted_ratings = user_watched_same_genre['title'].apply(
                lambda x: picked_userid_watched[picked_userid_watched['title'] == x]['rating'].values[0] *
                          similarity_score[x][picked_movie]).sum()

            weighted_similarities = user_watched_same_genre['title'].apply(
                lambda x: similarity_score[x][picked_movie]).sum()

            predicted_rating = weighted_ratings / weighted_similarities
        else:
            predicted_rating = 0  # Default rating if there are no similar movies watched

        # Save the predicted rating in the dictionary
        rating_prediction[picked_movie] = predicted_rating

    # Return the top recommended movies
    return sorted(rating_prediction.items(), key=operator.itemgetter(1), reverse=True)[:number_of_recommendations]

# Get recommendations for a user based on their ID
picked_user_id = 100  # Replace with the actual user ID
recommended_movies = rec_func(picked_user_id, number_of_similar_items=5, number_of_recommendations=10)
print(recommended_movies)
# Out:
# [('Ace Ventura: Pet Detective (1994)', 1.6189385516761479), ('Big Lebowski, The (1998)', 1.4663829600604312), ('Casablanca (1942)', 0.8139963132788641), ('Green Mile, The (1999)', 0.7569523184484308), ('Beetlejuice (1988)', 0.7318008582720874), ('Groundhog Day (1993)', 0.6371849862912703), ('Home Alone (1990)', 0.6365437967953071), ('Airplane! (1980)', 0.6327685048587328), ('Memento (2000)', 0.5562091073379178), ('Mrs. Doubtfire (1993)', 0.515871159201136)]
